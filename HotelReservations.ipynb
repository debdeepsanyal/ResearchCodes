# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/debdeepsanyal/Downloads/Hotel Reservations.csv")
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
correlation = df.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True)
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_26216/3771055671.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr().round(2)
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
sns.set(style="whitegrid")
sns.countplot(x='no_of_adults', data=df, palette= 'Set1')


plt.xlabel('Number of Adults')
plt.ylabel('Count')
plt.title('Distribution of Number of Adults')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_1782/1610047184.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='no_of_adults', data=df, palette= 'Set1')
# Text(0.5, 1.0, 'Distribution of Number of Adults')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.countplot(x='market_segment_type', data=df, palette='Set2')

# Set labels and title
plt.xlabel('Market Segments')
plt.ylabel('Count')
plt.title('Distribution of Market Segment Types')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_1782/1080142989.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='market_segment_type', data=df, palette='Set2')
# Text(0.5, 1.0, 'Distribution of Market Segment Types')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.countplot(x='arrival_year', data=df, palette='Set2')

# Set labels and title
plt.xlabel('Arrival Year')
plt.ylabel('Count')
plt.title('Distribution of Arrival Year')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_1782/432821172.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='arrival_year', data=df, palette='Set2')
# Text(0.5, 1.0, 'Distribution of Arrival Year')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.countplot(x='arrival_month', data=df, palette='Set2')

# Set labels and title
plt.xlabel('Number of Adults')
plt.ylabel('Count')
plt.title('Distribution of Number of Adults')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_10844/3655367956.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='arrival_month', data=df, palette='Set2')
# Text(0.5, 1.0, 'Distribution of Number of Adults')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.histplot(x='lead_time', data=df, palette='Set2', kde = True)

# Set labels and title
plt.xlabel('Number of Adults')
plt.ylabel('Count')
plt.title('Distribution of Number of Adults')
# Out:
# Text(0.5, 1.0, 'Distribution of Number of Adults')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.histplot(x='avg_price_per_room', data=df, palette='Set2', kde=True)

# Set labels and title
plt.xlabel('Average price per room')
plt.ylabel('Count')
plt.title('Distribution of average price per room')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_1782/4244832880.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='avg_price_per_room', data=df, palette='Set2', kde=True)
# Text(0.5, 1.0, 'Distribution of average price per room')

# %%
sns.set(style="whitegrid")

# Create a countplot using Seaborn
sns.histplot(x='arrival_date', data=df, palette='Set2', kde=True)

# Set labels and title
plt.xlabel('Number of Adults')
plt.ylabel('Count')
plt.title('Distribution of Number of Adults')
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_10844/1163334003.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='arrival_date', data=df, palette='Set2', kde=True)
# Text(0.5, 1.0, 'Distribution of Number of Adults')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit_transform(df['booking_status'])
df['booking_status'] = le.fit_transform(df['booking_status'])
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
correlation = df.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True)
# Out:
# /var/folders/fs/tjddsjl56hz4qgqkl9pt5h000000gn/T/ipykernel_1782/3771055671.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr().round(2)
# <Axes: >

# %%
def plot(col):
    for i in range(2):
        sns.kdeplot(data=df[df["booking_status"] == i][col], label='Not Cancelled' if i==1 else 'Cancelled')
    plt.legend()
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.title(f'Kernel Density Plot for {col} by Booking Status')

plot('lead_time')
plt.show()

# %%
class MultiColumnLabelEncoder:
    def __init__(self, columns=None):
        self.columns = columns  # array of column names to encode

    def fit(self, X, y=None):
        return self  # not relevant here

    def transform(self, X):
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                # Check if the column has null values
                if output[col].isnull().any():
                    # Apply LabelEncoder only to non-null values
                    mask = output[col].notnull()
                    output.loc[mask, col] = LabelEncoder().fit_transform(output.loc[mask, col])
                else:
                   output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname, col in output.iteritems():
                if col.isnull().any():
                    mask = col.notnull()
                    output.loc[mask, colname] = LabelEncoder().fit_transform(col[mask])
                else:
                    output[col] = LabelEncoder().fit_transform(output[col])

        return output

    def fit_transform(self, X, y=None):
        return self.fit(X, y).transform(X)

# %%
cat_f = df.select_dtypes(['object']).columns.to_list()
df = MultiColumnLabelEncoder(columns = cat_f).fit_transform(df)
df
# Out:
#        Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0               0             2               0                     1
# 1               1             2               0                     2
# 2               2             1               0                     2
# 3               3             2               0                     0
# 4               4             2               0                     1
# ...           ...           ...             ...                   ...
# 36270       36270             3               0                     2
# 36271       36271             2               0                     1
# 36272       36272             2               0                     2
# 36273       36273             2               0                     0
# 36274       36274             2               0                     1
#
#        no_of_week_nights  type_of_meal_plan  required_car_parking_space  \
# ...

# %%
sns.countplot(data=df, x=df['booking_status'], hue = df['booking_status'])
# Out:
# <Axes: xlabel='booking_status', ylabel='count'>

# %%
df = df.drop('Booking_ID', axis = 1)
df
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
from imblearn.over_sampling import SMOTE

x_train = df.drop('booking_status', axis = 1)
y_train = df['booking_status']

sm = SMOTE(random_state=1)
x_train, y_train = sm.fit_resample(x_train,y_train)

sns.countplot(x = y_train, hue = y_train)
# Out:
# <Axes: xlabel='booking_status', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler

sclaer = StandardScaler()
x_train = sclaer.fit_transform(x_train)
x_train
# Out:
# array([[ 0.31591069, -0.25060086,  0.26454486, ..., -0.07549468,
#         -1.16679381, -0.69374799],
#        [ 0.31591069, -0.25060086,  1.44078207, ..., -0.07549468,
#          0.04140588,  0.66434764],
#        [-1.65242797, -0.25060086,  1.44078207, ..., -0.07549468,
#         -1.31173139, -0.69374799],
#        ...,
#        [ 0.31591069, -0.25060086,  0.26454486, ..., -0.07549468,
#         -0.15223073, -0.69374799],
#        [ 0.31591069, -0.25060086, -0.91169234, ..., -0.07549468,
#          1.82761665,  0.66434764],
#        [ 0.31591069, -0.25060086,  0.26454486, ..., -0.07549468,
#         -0.87691865, -0.69374799]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.1, random_state=1)

# %%
from sklearn. naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

cv = StratifiedKFold(shuffle=True, random_state=1)

# %%
nb = GaussianNB()
nb_cv_scores = cross_val_score(nb, x_train, y_train, cv = cv, n_jobs = 5)
nb_cv_scores
# Out:
# array([0.56884182, 0.56166724, 0.56548975, 0.56640091, 0.56138952])

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
predicted = nb.predict(x_test)
nb_score = nb.score(x_test, y_test)
nb_score
# Out:
# 0.5623206232062321

# %%
classes = ['Not Cancelled', 'Cancelled']

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.99      0.69      2433
#            1       0.95      0.13      0.23      2445
#
#     accuracy                           0.56      4878
#    macro avg       0.74      0.56      0.46      4878
# weighted avg       0.74      0.56      0.46      4878

# %%
lr = LogisticRegression(C=3,penalty='elasticnet',l1_ratio=0.7, solver='saga')
lr_cv_scores = cross_val_score(lr, x_train, y_train, cv = cv, n_jobs=-1)
lr_cv_scores
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# array([0.79170937, 0.79888395, 0.78849658, 0.79157175, 0.78940774])

# %%
lr.fit(x_train, y_train)
predicted = lr.predict(x_test)
lr_score = lr.score(x_test, y_test)
lr_score
# Out:
# 0.8054530545305453

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81      2433
#            1       0.81      0.80      0.80      2445
#
#     accuracy                           0.81      4878
#    macro avg       0.81      0.81      0.81      4878
# weighted avg       0.81      0.81      0.81      4878

# %%
sv = SVC(C=1)
sv_cv_scores = cross_val_score(sv, x_train, y_train, cv = cv, n_jobs=-1)
sv_cv_scores
# Out:
# array([0.8389705 , 0.85081426, 0.83917995, 0.83986333, 0.8429385 ])

# %%
sv.fit(x_train, y_train)
predicted = sv.predict(x_test)
sv_score = sv.score(x_test, y_test)
sv_score
# Out:
# 0.8519885198851989

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('SVM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      2433
#            1       0.86      0.85      0.85      2445
#
#     accuracy                           0.85      4878
#    macro avg       0.85      0.85      0.85      4878
# weighted avg       0.85      0.85      0.85      4878

# %%
knn = KNeighborsClassifier(n_jobs = -1, n_neighbors=5)
knn_cv_scores = cross_val_score(knn, x_train, y_train, cv = cv, n_jobs=-1)
knn_cv_scores
# Out:
# array([0.85662225, 0.86539119, 0.86173121, 0.85649203, 0.85694761])

# %%
knn.fit(x_train, y_train)
predicted = knn.predict(x_test)
knn_score = knn.score(x_test, y_test)
knn_score
# Out:
# 0.8782287822878229

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      2433
#            1       0.89      0.87      0.88      2445
#
#     accuracy                           0.88      4878
#    macro avg       0.88      0.88      0.88      4878
# weighted avg       0.88      0.88      0.88      4878

# %%
rvc = RandomForestClassifier(n_jobs = -1, n_estimators=250)
rvc_cv_scores = cross_val_score(rvc, x_train, y_train, cv = cv, n_jobs = -1)
rvc_cv_scores
# Out:
# array([0.91959913, 0.92426831, 0.9143508 , 0.91560364, 0.9191344 ])

# %%
rvc.fit(x_train, y_train)
predicted = rvc.predict(x_test)
rvc_score = rvc.score(x_test, y_test)
rvc_score
# Out:
# 0.9321443214432145

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('Random Forest Classifier Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      2433
#            1       0.93      0.94      0.93      2445
#
#     accuracy                           0.93      4878
#    macro avg       0.93      0.93      0.93      4878
# weighted avg       0.93      0.93      0.93      4878

# %%
xgb = XGBClassifier(n_jobs = -1)
xgb_cv_scores = cross_val_score(xgb, x_train, y_train, cv = cv, n_jobs=-1)
xgb_cv_scores
# Out:
# array([0.89978362, 0.90137798, 0.89840547, 0.89817768, 0.8998861 ])

# %%
xgb.fit(x_train, y_train)
predicted = xgb.predict(x_test)
xgb_score = xgb.score(x_test, y_test)
xgb_score
# Out:
# 0.9114391143911439

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('XGB Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      2433
#            1       0.91      0.92      0.91      2445
#
#     accuracy                           0.91      4878
#    macro avg       0.91      0.91      0.91      4878
# weighted avg       0.91      0.91      0.91      4878

# %%
from sklearn.ensemble import ExtraTreesClassifier

ext = ExtraTreesClassifier(n_jobs = -1, n_estimators=250)
ext_cv_scores = cross_val_score(ext, x_train, y_train, cv = cv, n_jobs=-1)
ext_cv_scores
# Out:
# array([0.91242455, 0.91777702, 0.91138952, 0.91047836, 0.91378132])

# %%
ext.fit(x_train, y_train)
predicted = ext.predict(x_test)
ext_score = ext.score(x_test, y_test)
ext_score
# Out:
# 0.922919229192292

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      2433
#            1       0.92      0.93      0.92      2445
#
#     accuracy                           0.92      4878
#    macro avg       0.92      0.92      0.92      4878
# weighted avg       0.92      0.92      0.92      4878

# %%
cm = confusion_matrix(y_test, predicted)

# Plot the confusion matrix using Seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='GnBu', xticklabels=classes, yticklabels=classes)
plt.title('XGB Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
sclf = StackingClassifier(classifiers=[ext, rvc, xgb], meta_classifier=lr)
sclf.fit(x_train, y_train)
y_pred = sclf.predict(x_train)

# Check if there are NaN values in the predictions
print("NaN in predictions:", np.isnan(y_pred).any())
# Out:
# NaN in predictions: False

# %%
import warnings

warnings.simplefilter('ignore')

# %%
sclf = StackingClassifier(classifiers=[rvc, lr, knn], meta_classifier=knn)
print('3-fold cross validation:\n')

for clf, label in zip([rvc, lr, knn, sclf], 
                      ['Random Trees', 
                       'lr', 
                       'KNN',
                       'StackingClassifier']):

    scores = cross_val_score(clf, x_train, y_train, cv = 5, n_jobs=-1)
    print("Accuracy: %0.4f (+/- %0.4f) [%s]" 
          % (scores.mean(), scores.std(), label))
# Out:
# 3-fold cross validation:
#
# Accuracy: 0.9185 (+/- 0.0025) [Random Trees]
# Accuracy: 0.7919 (+/- 0.0037) [lr]
# Accuracy: 0.8599 (+/- 0.0030) [KNN]
# Accuracy: 0.9185 (+/- 0.0025) [StackingClassifier]

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

y_prob = rvc.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
feature_importances = rvc.feature_importances_

# Get feature names (assuming they are available)
feature_names = df.columns

# Sort indices in descending order based on feature importances
indices = feature_importances.argsort()[::-1]

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(x_train.shape[1]), feature_importances[indices], align='center')
plt.yticks(range(x_train.shape[1]), [feature_names[i] for i in indices])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance in Random Forest Classifier')
plt.show()

# %%
import os, shutil, pathlib

# %%
original_dir = pathlib.Path("/Users/debdeepsanyal/Desktop/train")
new_base_dir = pathlib.Path("/Users/debdeepsanyal/Desktop/cats_vs_dogs_small")

# %%
original_dir = pathlib.Path("/Users/debdeepsanyal/Desktop/train")
new_base_dir = pathlib.Path("/Users/debdeepsanyal/Desktop/cats_vs_dogs_small")

def make_subset(subset_name, start, end):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        if not os.path.exists(dir):
            os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start, end)]
        for fname in fnames:
            src = original_dir / fname
            dst = dir / fname
            print(f"Copying {src} to {dst}")  # Add debugging output
            shutil.copyfile(src=src, dst=dst)

# Define the ranges for subsets
ranges = [("train", 0, 1000), ("validation", 1000, 1500), ("test", 1500, 2500)]

# Use make_subset function for each subset
for subset_name, start, end in ranges:
    make_subset(subset_name, start, end)
# Out:
# Copying /Users/debdeepsanyal/Desktop/train/cat.0.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.0.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.1.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.1.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.2.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.2.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.3.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.3.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.4.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.4.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.5.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.5.jpg
# Copying /Users/debdeepsanyal/Desktop/train/cat.6.jpg to /Users/debdeepsanyal/Desktop/cats_vs_dogs_small/train/cat/cat.6.jpg
# ...

# %%
def get_iou(boxA, boxB, eps = 1e-5):
    ax, ay, ah, aw = [boxA[i] for i in range(4)]
    bx, by, bh, bw = [boxB[i] for i in range(4)]

    inner_length = inner_breadth = 0

    a_wid = ay + aw
    a_len = ax + ah
    b_wid = by + bw
    b_len = bx + bh


    if a_wid > by and by > ay:
        inner_breadth = a_wid - by
    elif b_wid > ay and ay > by:
        inner_breadth = b_wid - ay
    
    
    
    if a_len > bx:
        inner_length = a_len - bx
    
    elif b_len > ax:
        inner_length = b_len - ax
    
    inter_area = inner_length * inner_breadth
